# %%
import basedosdados as bd

# Para carregar o dado direto no pandas
df = bd.read_table(dataset_id='br_mobilidados_indicadores',
table_id='tempo_deslocamento_casa_trabalho',
billing_project_id="trabalho-374700")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 import basedosdados as bd
#       3 # Para carregar o dado direto no pandas
#       4 df = bd.read_table(dataset_id='br_mobilidados_indicadores',
#       5 table_id='tempo_deslocamento_casa_trabalho',
#       6 billing_project_id="trabalho-374700")
#
# File ~/.local/lib/python3.8/site-packages/basedosdados/__init__.py:16
#      13 #pylint: disable=C0413
#      15 from basedosdados.constants import constants, config
# ---> 16 from basedosdados.upload.dataset import Dataset
#      17 from basedosdados.upload.storage import Storage
#      18 from basedosdados.upload.table import Table
#
# File ~/.local/lib/python3.8/site-packages/basedosdados/upload/dataset.py:8
#       5 from pathlib import Path
#       6 from loguru import logger
# ----> 8 from google.cloud import bigquery
# ...
