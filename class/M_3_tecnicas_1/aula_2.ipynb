# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import image as img

R = 0
G = 1
B = 2
A = 3

image = img.imread('python.jpg')
image

#image.shape
#image.ndim

#plt.imshow(image)

#plt.imshow(image[:,:,B], cmap='gray')
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
image.shape
# Out:
# (277, 400, 3)

# %%
image.ndim
# Out:
# 3

# %%
plt.imshow(image)

# %%
B = 2
plt.imshow(image[:,:, B], cmap='gray')

# %%
image_random = np.random.random(low=0, high=255, size=(100, 100, 4), dtype=float)
image_random
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 image_random = np.random.random(low=0, high=255, size=(100, 100, 4), dtype=float)
#       2 image_random
#
# File mtrand.pyx:427, in numpy.random.mtrand.RandomState.random()
#
# TypeError: random() got an unexpected keyword argument 'low'

# %%
image1 = image
image2 = image
image3 = image

# %%
#Array!D
array1D = np.array([1,2,3])
array1D
array1D.shape
array1D.ndim
array1D.size
# Out:
# 3

# %%
#Array2D

array2D = np.array([[1,2,3], [1,2,3]])
array2D.ndim
# Out:
# 2

# %%
#Array3D

array2D.sum(axis=0)
# Out:
# array([2, 4, 6])

# %%
array2D.sum(axis=1)
# Out:
# array([6, 6])
